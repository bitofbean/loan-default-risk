# %%
import pandas as pd

# Read your CSV file
df = pd.read_csv('datamart/gold/model_predictions/predictions_2024_04_01.csv')

# Round predicted_probability to 2 decimal places
df['predicted_probability'] = df['predicted_probability'].round(2)

# Save the updated file
df.to_csv('datamart/gold/model_predictions/predictions_2024_04_01.csv', index=False)

# Display the result
print("Updated predicted_probability column:")
df.head(20)
# Out:
# Updated predicted_probability column:
#    Customer_ID snapshot_date           model_name  predicted_label  \
# 0   CUS_0x1ed5    2024-04-01  logistic_regression                0
# 1   CUS_0xb38d    2024-04-01  logistic_regression                0
# 2   CUS_0x7e8d    2024-04-01  logistic_regression                1
# 3   CUS_0x5479    2024-04-01  logistic_regression                0
# 4    CUS_0x748    2024-04-01  logistic_regression                1
# 5   CUS_0x50ef    2024-04-01  logistic_regression                0
# 6   CUS_0x3966    2024-04-01  logistic_regression                0
# 7   CUS_0x727e    2024-04-01  logistic_regression                0
# 8   CUS_0x24ae    2024-04-01  logistic_regression                0
# 9    CUS_0xc04    2024-04-01  logistic_regression                0
# 10  CUS_0x4f29    2024-04-01  logistic_regression                0
# 11  CUS_0x80bd    2024-04-01  logistic_regression                0
# ...
